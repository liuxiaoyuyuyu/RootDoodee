# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
file = 'Root_Insurance_Data.csv'
df = pd.read_csv(file)

# %%
df_train = df.iloc[:int(len(df)*0.75),:].copy()
df_test = df.iloc[int(len(df)*0.75):,:].copy()

# %%
f, ax = plt.subplots(figsize=(5,3),dpi=100)
sns.histplot(data=df_train,x='Currently Insured',hue='policies_sold',stat='probability',shrink=0.5,discrete=True,multiple="stack")
plt.show()

# %%
y1 = df_train[df_train['Number of Vehicles']==1].groupby('policies_sold').count()
p1 = y1.iloc[1,1]/(y1.iloc[0,1]+y1.iloc[1,1])
y2 = df_train[df_train['Number of Vehicles']==2].groupby('policies_sold').count()
p2 = y2.iloc[1,1]/(y2.iloc[0,1]+y2.iloc[1,1])
y3 = df_train[df_train['Number of Vehicles']==3].groupby('policies_sold').count()
p3 = y3.iloc[1,1]/(y3.iloc[0,1]+y3.iloc[1,1])

# %%
plt.figure(figsize=(5,3),dpi=100)
sns.histplot(data=df_train,x='Number of Vehicles',hue='policies_sold',discrete=True,shrink=0.5,multiple="stack")
plt.show()

# %%
f,ax = plt.subplots(figsize=(5,3),dpi=100)
ax.scatter([1,2,3],[p1,p2,p3],alpha=0.5)
ax.set_xlabel('Number of Vehiles')
ax.set_ylabel('Probability of Policies Sold')
plt.show()

# %%
f, ax = plt.subplots(figsize=(5,3),dpi=100)
sns.histplot(data=df_train,x='Number of Drivers',hue='policies_sold',stat='probability',discrete=True,shrink=0.3,multiple="stack")
plt.show()

# %%
f, ax = plt.subplots(figsize=(5,3),dpi=100)
sns.histplot(data=df_train,x='Marital Status',hue='policies_sold',stat='probability',discrete=True,shrink=0.3,multiple="stack")
plt.show()

# %%
f, ax = plt.subplots(figsize=(5,3),dpi=100)
sns.histplot(data=df_train,x='Currently Insured',hue='click',stat='probability',discrete=True,shrink=0.5,multiple="stack")
plt.show()

# %%
f, ax = plt.subplots(figsize=(5,3),dpi=100)
sns.histplot(data=df_train,x='Number of Vehicles',hue='click',stat='probability',discrete=True,shrink=0.5,multiple="stack")
plt.show()

# %%
f, ax = plt.subplots(figsize=(5,3),dpi=100)
sns.histplot(data=df_train,x='Number of Drivers',hue='click',stat='probability',discrete=True,shrink=0.3,multiple="stack")
plt.show()

# %%
f, ax = plt.subplots(figsize=(5,3),dpi=100)
sns.histplot(data=df_train,x='Marital Status',hue='click',stat='probability',discrete=True,shrink=0.3,multiple="stack")
plt.show()

# %%
y1 = df_train[df_train['Number of Vehicles']==1].groupby('click').count()
p1 = y1.iloc[1,1]/(y1.iloc[0,1]+y1.iloc[1,1])
y2 = df_train[df_train['Number of Vehicles']==2].groupby('click').count()
p2 = y2.iloc[1,1]/(y2.iloc[0,1]+y2.iloc[1,1])
y3 = df_train[df_train['Number of Vehicles']==3].groupby('click').count()
p3 = y3.iloc[1,1]/(y3.iloc[0,1]+y3.iloc[1,1])
f,ax = plt.subplots(figsize=(5,3),dpi=100)
ax.scatter([1,2,3],[p1,p2,p3],alpha=0.5)
ax.set_xlabel('Number of Vehicles')
ax.set_ylabel('Probability of Click')
plt.show()

# %%
res = []
feature = ['11','12','21','22','31','32']
for i in range(len(df_train)):
    if df_train.iloc[i,1] == 1 and df_train.iloc[i,2] == 1:
        res.append('11')
    elif df_train.iloc[i,1] == 1 and df_train.iloc[i,2] == 2: 
        res.append('12')
    elif df_train.iloc[i,1] == 2 and df_train.iloc[i,2] == 1: 
        res.append('21')
    elif df_train.iloc[i,1] == 2 and df_train.iloc[i,2] == 2:
        res.append('22')
    elif df_train.iloc[i,1] == 3 and df_train.iloc[i,2] == 1: 
        res.append('31')
    else:
        res.append('32')
df_train['Vehicle_Driver'] = res

# %%
f, ax = plt.subplots(figsize=(5,3),dpi=100)
sns.histplot(data=df_train,x='Vehicle_Driver',hue='policies_sold',stat='probability',discrete=True,shrink=0.3,multiple="stack")
plt.show()

# %%
f, ax = plt.subplots(figsize=(5,3),dpi=100)
sns.histplot(data=df_train,x='Vehicle_Driver',hue='click',stat='probability',discrete=True,shrink=0.3,multiple="stack")
plt.show()

# %%
res = []
feature = ['1s','1m','2s','2m','3s','3m']
for i in range(len(df_train)):
    if df_train.iloc[i,1] == 1 and df_train.iloc[i,3] == 'S':
        res.append('1s')
    elif df_train.iloc[i,1] == 1 and df_train.iloc[i,3] == 'M': 
        res.append('1m')
    elif df_train.iloc[i,1] == 2 and df_train.iloc[i,3] == 'S': 
        res.append('2s')
    elif df_train.iloc[i,1] == 2 and df_train.iloc[i,3] == 'M':
        res.append('2m')
    elif df_train.iloc[i,1] == 3 and df_train.iloc[i,3] == 'S': 
        res.append('3s')
    else:
        res.append('3m')
df_train['Vehicle_Marital'] = res

# %%
f, ax = plt.subplots(figsize=(5,3),dpi=100)
sns.histplot(data=df_train,x='Vehicle_Marital',hue='policies_sold',stat='probability',discrete=True,shrink=0.3,multiple="stack")
plt.show()

# %%
f, ax = plt.subplots(figsize=(5,3),dpi=100)
sns.histplot(data=df_train,x='Vehicle_Marital',hue='click',stat='probability',discrete=True,shrink=0.3,multiple="stack")
plt.show()
